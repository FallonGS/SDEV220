# %%
## Author: Fallon Skeens
## Assignment 4.1
## This code takes compares 'guess' to 'secret' and determines 
##  whether it is too high, too low, or just right.

secret = 5
guess = 1
if guess < secret:
    print("Too low")
elif guess > secret:
    print("Too high")
else:
    print("Just right")
# Out:
# Too low

# %%
small = True
green = False

if small and green:
    print("Pea")
elif small and not green:
    print("Cherry")
elif not small and green:
    print("Watermelon")
else:
    print("Pumpkin")
# Out:
# Cherry

# %%
numbers = [3, 2, 1, 0]

for n in numbers:
    print(n)
# Out:
# 3
# 2
# 1
# 0

# %%
guess_me = 7
number = 1

while True:
    if number < guess_me:
        print("Too low")
    elif number == guess_me:
        print("Found it!")
        break
    else:
        print("Oops")
        break

    number += 1
# Out:
# Too low
# Too low
# Too low
# Too low
# Too low
# Too low
# Found it!

# %%
guess_me = 5

for number in range(10):
    if number < guess_me:
        print("
